# %% [markdown]
# # A First Look At PyROOT
#
# This is an example of what you might do when you first look at some root files that you've never seen before. In this exercise, we will imagine that we're just getting started on some sort of dijet resonance analysis. Luckily, your signal, backgrounds, and data have all been ntuplized already, and the output ntuples are located on Fermilab eos at:
#
# `/store/user/hats/PyRoot/2017/qcd_samples`
#
# In Jupyter, we can execute shell commands by prepending the usual commands with `!`
#
# The following command is actually two steps:
#
# * The `xrdfs` command lists (AKA `ls`) the files stored on the USA-based xrootd redirector `cmsxrootd.fnal.gov` in the directory `/store/user/hats/PyRoot/2017/qcd_samples`
# * That command is "piped" (via the `|` symbol) into `sort -u`, which removes duplicate lines
#
# We have to remove duplicate lines because `xrdfs` has an annoying habit of listing the file N number of times where N is the number of physical backend servers.

# %%
# !xrdfs root://xrootd.accre.vanderbilt.edu/ ls /store/user/hats/PyRoot/2017/qcd_samples | sort -u
# Out:
# [!] Some of the requests failed. The result may be incomplete.
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT1000to1500_0_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT1000to1500_0_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT1000to1500_0_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT1000to1500_0_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT1500to2000_0_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT1500to2000_0_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT1500to2000_0_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT1500to2000_0_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT2000toInf_0_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT2000toInf_0_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT2000toInf_0_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT2000toInf_0_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_0_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_0_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_0_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_0_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_1_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_1_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_1_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_1_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_2_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_2_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_2_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_2_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_3_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_3_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_3_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT200to300_3_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_0_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_0_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_0_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_0_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_1_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_1_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_1_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_1_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_2_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_2_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_2_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT300to500_2_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_0_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_0_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_0_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_0_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_1_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_1_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_1_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_1_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_2_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_2_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_2_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_2_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_3_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_3_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_3_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT500to700_3_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_0_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_0_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_0_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_0_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_1_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_1_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_1_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_1_3
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_2_0
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_2_1
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_2_2
# /store/user/hats/PyRoot/2017/qcd_samples/QCD_HT700to1000_2_3
# /store/user/hats/PyRoot/2017/qcd_samples/jhak.test
# /store/user/hats/PyRoot/2017/qcd_samples/recursiveFileList.py
# /store/user/hats/PyRoot/2017/qcd_samples/recursiveFileList.pyc
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_data
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig
# /store/user/hats/PyRoot/2017/qcd_samples/xrdcpRecursive.py

# %% [markdown]
# Let's see our signal samples, which are in `shuffled_sig`:

# %%
# !xrdfs root://xrootd.accre.vanderbilt.edu/ ls /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig | sort | uniq
# Out:
# [!] Some of the requests failed. The result may be incomplete.
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_0.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_1.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_10.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_11.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_12.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_13.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_14.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_15.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_16.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_17.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_18.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_19.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_2.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_3.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_4.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_5.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_6.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_7.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_8.root
# /store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_9.root

# %% [markdown]
# As you can tell, these commands take some time to return,
#
# Let's use pyROOT to take a look at the basic structure of the file and the branches therein.
#
# > Note:
# >   One could do all of this in an interactive python session, using
# >
# >   `python -i`
# >
# >  Interactive pyROOT is very useful for quickly looking at ROOT files and other tasks, such as formatting ROOT graphics. If you are interested in this, please ask the instructor for a demonstration of where this can come in handy (e.g. reformatting plots in interactive pyROOT while a TCanvas is open).

# %% [markdown]
# Commonly, pyROOT scripts start out with
#
# `from ROOT import *`
#
# but this is not allowed in JupyROOT. However, we can still save some typing by referring to ROOT with a shorter name:

# %%
from ROOT import *
# Out:
# Welcome to JupyROOT 6.14/09
# /cvmfs/cms.cern.ch/slc7_amd64_gcc820/lcg/root/6.14.09/lib/ROOT.py:577: UserWarning: "from ROOT import *" is not supported under IPython
#   warnings.warn( '"from ROOT import *" is not supported under IPython' )

# %%
import ROOT as r

# %% [markdown]
# Once we've loaded ROOT, we can load our files remotely, without having to transfer them to our local machine first.
#
# If you get an `Auth Failed` error, make sure that you have a valid grid proxy with `voms-proxy-init -voms cms -valid 192:0`
#
# (note, we're hardcoding a specific host with this file here -- this is due to a bug in the current xrootd server version, which should be fixed soon)

# %%
# Note the double-slash ("//") between the hostname and store. This is required.
firstLookFile = r.TFile.Open("root://xrootd.accre.vanderbilt.edu//store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_0.root")

# %%
firstLookFile.ls()
# Out:
# TNetXNGFile**		root://xrootd.accre.vanderbilt.edu//store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_0.root
#  TNetXNGFile*		root://xrootd.accre.vanderbilt.edu//store/user/hats/PyRoot/2017/qcd_samples/shuffled_sig/sig_shuffled_0.root
#   KEY: TTree	tree;1	tree

# %%
firstLookTree = firstLookFile.Get("tree")

# %% [markdown]
# Already, we're benefitting from pyROOT's syntax. Note that a similar step in an interactive ROOT session would require a bit more effort:
#
# `TTree* firstLookTree = (TTree*) firstLookFile->Get("tree")`

# %% [markdown]
# Let's use a quick python loop to list all the branches in our tree.

# %%
for branch in firstLookTree.GetListOfBranches():
    print branch.GetName()
# Out:
# ph_N
# ph_pdgId
# ph_charge
# ph_e
# ph_eta
# ph_phi
# ph_mass
# ph_pt
# ph_et
# ph_rho
# ph_superCluster_eta
# ph_superCluster_phi
# ph_sigmaIetaIeta
# ph_hOverE
# ph_isoGamma
# ph_isoCh
# ph_passEleVeto
# ph_passLooseId
# ph_passMediumId
# ph_passTightId
# ph_mvaVal
# ph_mvaCat
# rho
# jetAK4_N
# jetAK4_pt
# jetAK4_eta
# jetAK4_mass
# jetAK4_phi
# jetAK4_e
# jetAK4_jec
# jetAK4_jecUp
# jetAK4_jecDown
# jetAK4_IDLoose
# jetAK4_IDTight
# jetAK4_IDTightLepVeto
# jetAK4_charge
# jetAK4_csv
# jetAK4_vtxMass
# jetAK4_vtxNtracks
# jetAK4_vtx3DVal
# jetAK4_vtx3DSig
# jetAK4_partonFlavour
# jetAK4_hadronFlavour
# jetAK4_genParton_pdgID
# jetAK4_nbHadrons
# jetAK4_ncHadrons
# jetAK4_jer_sf
# jetAK4_jer_sf_up
# jetAK4_jer_sf_down
# jetAK4_jer_sigma_pt
# jetAK8_N
# jetAK8_pt
# jetAK8_eta
# jetAK8_mass
# jetAK8_phi
# jetAK8_e
# jetAK8_jec
# jetAK8_jecUp
# jetAK8_jecDown
# jetAK8_IDLoose
# jetAK8_IDTight
# jetAK8_IDTightLepVeto
# jetAK8_charge
# jetAK8_partonFlavour
# jetAK8_hadronFlavour
# jetAK8_genParton_pdgID
# jetAK8_nbHadrons
# jetAK8_ncHadrons
# jetAK8_jer_sf
# jetAK8_jer_sf_up
# jetAK8_jer_sf_down
# jetAK8_jer_sigma_pt
# jetAK8Puppi_jer_sf
# jetAK8Puppi_jer_sf_up
# jetAK8Puppi_jer_sf_down
# jetAK8Puppi_jer_sigma_pt
# jetAK8_Hbbtag
# jetAK8_csv
# jetAK8_tau1
# jetAK8_tau2
# jetAK8_tau3
# jetAK8_pruned_mass
# jetAK8_pruned_massCorr
# jetAK8_pruned_jec
# jetAK8_pruned_jecUp
# jetAK8_pruned_jecDown
# jetAK8_softdrop_mass
# jetAK8_softdrop_massCorr
# jetAK8_softdrop_jec
# jetAK8_softdrop_jecUp
# jetAK8_softdrop_jecDown
# jetAK8_subjet_softdrop_N
# jetAK8_subjet_softdrop_pt
# jetAK8_subjet_softdrop_eta
# jetAK8_subjet_softdrop_mass
# jetAK8_subjet_softdrop_phi
# jetAK8_subjet_softdrop_e
# jetAK8_subjet_softdrop_charge
# jetAK8_subjet_softdrop_genParton_pdgID
# jetAK8_subjet_softdrop_nbHadrons
# jetAK8_subjet_softdrop_ncHadrons
# jetAK8_subjet_softdrop_partonFlavour
# jetAK8_subjet_softdrop_hadronFlavour
# jetAK8_subjet_softdrop_csv
# jetAK8_puppi_pt
# jetAK8_puppi_eta
# jetAK8_puppi_mass
# jetAK8_puppi_phi
# jetAK8_puppi_e
# jetAK8_puppi_pruned_mass
# jetAK8_puppi_pruned_massCorr
# jetAK8_puppi_pruned_jec
# jetAK8_puppi_softdrop_mass
# jetAK8_puppi_softdrop_massCorr
# jetAK8_puppi_softdrop_jec
# jetAK8_puppi_tau1
# jetAK8_puppi_tau2
# jetAK8_puppi_tau3
# jetAK8_subjet_puppi_softdrop_N
# jetAK8_subjet_puppi_softdrop_pt
# jetAK8_subjet_puppi_softdrop_eta
# jetAK8_subjet_puppi_softdrop_mass
# jetAK8_subjet_puppi_softdrop_phi
# jetAK8_subjet_puppi_softdrop_e
# jetAK8_subjet_puppi_softdrop_charge
# jetAK8_subjet_puppi_softdrop_genParton_pdgID
# jetAK8_subjet_puppi_softdrop_nbHadrons
# jetAK8_subjet_puppi_softdrop_ncHadrons
# jetAK8_subjet_puppi_softdrop_partonFlavour
# jetAK8_subjet_puppi_softdrop_hadronFlavour
# jetAK8_subjet_puppi_softdrop_csv
# jetAK8_subjet_pruned_N
# jetAK8_subjet_pruned_pt
# jetAK8_subjet_pruned_eta
# jetAK8_subjet_pruned_mass
# jetAK8_subjet_pruned_phi
# jetAK8_subjet_pruned_e
# jetAK8_subjet_pruned_charge
# jetAK8_subjet_pruned_genParton_pdgID
# jetAK8_subjet_pruned_nbHadrons
# jetAK8_subjet_pruned_ncHadrons
# jetAK8_subjet_pruned_partonFlavour
# jetAK8_subjet_pruned_hadronFlavour
# jetAK8_subjet_pruned_csv
# HLT_isFired
# passFilter_HBHE
# passFilter_HBHELoose
# passFilter_HBHETight
# passFilter_HBHEIso
# passFilter_CSCHalo
# passFilter_CSCTightHalo2015
# passFilter_HCALlaser
# passFilter_ECALDeadCell
# passFilter_GoodVtx
# passFilter_TrkFailure
# passFilter_EEBadSc
# passFilter_ECALlaser
# passFilter_TrkPOG
# passFilter_TrkPOG_manystrip
# passFilter_TrkPOG_toomanystrip
# passFilter_TrkPOG_logError
# passFilter_METFilters
# passFilter_CSCTightHaloTrkMuUnvetoFilter
# passFilter_globalTightHalo2016
# passFilter_HcalStripHalo
# passFilter_chargedHadronTrackResolution
# passFilter_muonBadTrack
# EVENT_event
# EVENT_run
# EVENT_lumiBlock
# PV_N
# PV_filter
# PV_chi2
# PV_ndof
# PV_rho
# PV_z

# %% [markdown]
# Our analysis is going to look for dijet resonances using AK4 jets. So to get a feel for the data, let's look at what the AK4 jet pT spectrum looks like.

# %%
can = r.TCanvas()      
firstLookTree.Draw("jetAK4_pt")
can.Draw()

# %% [markdown]
# > Note that in interactive pyROOT, one can simply call `firstLookTree.Draw("jetAK4_pt")` without bothering to explicitly instantiate a TCanvas and call TCanvas.Draw() on it
#
# Let's do some quick changes to the plot. `r.gStyle` gives us access to common style changes for ROOT graphics.

# %%
r.gStyle.SetOptStat(0)
can.SetLogy()
can.Draw()

# %% [markdown]
# Let's quickly demonstrate python's introspection features. ROOT automatically builds a lot of things into a TCanvas that might not be obvious when you simply call `TTree.Draw('branchName')`, so let's see what's in our canvas and what methods we could call on it. And let's make the output more readable while we're at it.

# %%
import inspect
from pprint import pprint
for primitive in can.GetListOfPrimitives():
    print primitive, pprint(inspect.getmembers(primitive, predicate=inspect.ismethod))
# Out:
# <ROOT.TFrame object ("TFrame") at 0x6880400>[('AbstractMethod', <ROOT.MethodProxy object at 0x7f5a300915d0>),
#  ('AppendPad', <ROOT.MethodProxy object at 0x7f5a30091610>),
#  ('Browse', <ROOT.MethodProxy object at 0x7f5a30091650>),
#  ('CheckedHash', <ROOT.MethodProxy object at 0x7f5a30091690>),
#  ('Class', <ROOT.MethodProxy object at 0x7f5a300916d0>),
#  ('ClassName', <ROOT.MethodProxy object at 0x7f5a30091710>),
#  ('Class_Name', <ROOT.MethodProxy object at 0x7f5a30091750>),
#  ('Class_Version', <ROOT.MethodProxy object at 0x7f5a30091790>),
#  ('Clear', <ROOT.MethodProxy object at 0x7f5a300917d0>),
#  ('Clone', <ROOT.MethodProxy object at 0x7f5a30091810>),
#  ('Compare', <ROOT.MethodProxy object at 0x7f5a30091850>),
#  ('Copy', <ROOT.MethodProxy object at 0x7f5a30091890>),
#  ('DeclFileLine', <ROOT.MethodProxy object at 0x7f5a300918d0>),
#  ('DeclFileName', <ROOT.MethodProxy object at 0x7f5a30091910>),
#  ('Delete', <ROOT.MethodProxy object at 0x7f5a30091950>),
#  ('Dictionary', <ROOT.MethodProxy object at 0x7f5a30091990>),
#  ('DistancetoLine', <ROOT.MethodProxy object at 0x7f5a300919d0>),
#  ('DistancetoPrimitive', <ROOT.MethodProxy object at 0x7f5a30091a10>),
#  ('Draw', <ROOT.MethodProxy object at 0x7f5a30091a50>),
#  ('DrawBox', <ROOT.MethodProxy object at 0x7f5a30091a90>),
#  ('DrawClass', <ROOT.MethodProxy object at 0x7f5a30091ad0>),
#  ('DrawClone', <ROOT.MethodProxy object at 0x7f5a30091b10>),
#  ('DrawWbox', <ROOT.MethodProxy object at 0x7f5a30091b50>),
#  ('Dump', <ROOT.MethodProxy object at 0x7f5a30091b90>),
#  ('Error', <ROOT.MethodProxy object at 0x7f5a30091bd0>),
#  ('Execute', <ROOT.MethodProxy object at 0x7f5a30091c10>),
#  ('ExecuteEvent', <ROOT.MethodProxy object at 0x7f5a30091c50>),
#  ('Fatal', <ROOT.MethodProxy object at 0x7f5a30091c90>),
#  ('FindObject', <ROOT.MethodProxy object at 0x7f5a30091cd0>),
#  ('GetBBox', <ROOT.MethodProxy object at 0x7f5a30091d10>),
#  ('GetBBoxCenter', <ROOT.MethodProxy object at 0x7f5a30091d50>),
#  ('GetBorderMode', <ROOT.MethodProxy object at 0x7f5a30091d90>),
#  ('GetBorderSize', <ROOT.MethodProxy object at 0x7f5a30091dd0>),
#  ('GetDarkColor', <ROOT.MethodProxy object at 0x7f5a30091e10>),
#  ('GetDrawOption', <ROOT.MethodProxy object at 0x7f5a30091e90>),
#  ('GetDtorOnly', <ROOT.MethodProxy object at 0x7f5a30091ed0>),
#  ('GetFillColor', <ROOT.MethodProxy object at 0x7f5a30091f10>),
#  ('GetFillStyle', <ROOT.MethodProxy object at 0x7f5a30091f50>),
#  ('GetIconName', <ROOT.MethodProxy object at 0x7f5a30091f90>),
#  ('GetLightColor', <ROOT.MethodProxy object at 0x7f5a30091fd0>),
#  ('GetLineColor', <ROOT.MethodProxy object at 0x7f5a30092050>),
#  ('GetLineStyle', <ROOT.MethodProxy object at 0x7f5a30092090>),
#  ('GetLineWidth', <ROOT.MethodProxy object at 0x7f5a300920d0>),
#  ('GetName', <ROOT.MethodProxy object at 0x7f5a30092110>),
#  ('GetObjectInfo', <ROOT.MethodProxy object at 0x7f5a30092150>),
#  ('GetObjectStat', <ROOT.MethodProxy object at 0x7f5a30092190>),
#  ('GetOption', <ROOT.MethodProxy object at 0x7f5a300921d0>),
#  ('GetTitle', <ROOT.MethodProxy object at 0x7f5a30092210>),
#  ('GetUniqueID', <ROOT.MethodProxy object at 0x7f5a30092250>),
#  ('GetX1', <ROOT.MethodProxy object at 0x7f5a30092290>),
#  ('GetX2', <ROOT.MethodProxy object at 0x7f5a300922d0>),
#  ('GetY1', <ROOT.MethodProxy object at 0x7f5a30092310>),
#  ('GetY2', <ROOT.MethodProxy object at 0x7f5a30092350>),
#  ('HandleTimer', <ROOT.MethodProxy object at 0x7f5a30092390>),
#  ('HasInconsistentHash', <ROOT.MethodProxy object at 0x7f5a300923d0>),
#  ('Hash', <ROOT.MethodProxy object at 0x7f5a30092410>),
#  ('HideToolTip', <ROOT.MethodProxy object at 0x7f5a30092450>),
#  ('ImplFileLine', <ROOT.MethodProxy object at 0x7f5a30092490>),
#  ('ImplFileName', <ROOT.MethodProxy object at 0x7f5a300924d0>),
#  ('Info', <ROOT.MethodProxy object at 0x7f5a30092510>),
#  ('InheritsFrom', <ROOT.MethodProxy object at 0x7f5a30092550>),
#  ('Inspect', <ROOT.MethodProxy object at 0x7f5a30092590>),
#  ('InvertBit', <ROOT.MethodProxy object at 0x7f5a300925d0>),
#  ('IsA', <ROOT.MethodProxy object at 0x7f5a30092610>),
#  ('IsBeingResized', <ROOT.MethodProxy object at 0x7f5a30092650>),
#  ('IsEqual', <ROOT.MethodProxy object at 0x7f5a30092690>),
#  ('IsFolder', <ROOT.MethodProxy object at 0x7f5a300926d0>),
#  ('IsInside', <ROOT.MethodProxy object at 0x7f5a30092710>),
#  ('IsOnHeap', <ROOT.MethodProxy object at 0x7f5a30092750>),
#  ('IsSortable', <ROOT.MethodProxy object at 0x7f5a30092790>),
#  ('IsTransparent', <ROOT.MethodProxy object at 0x7f5a300927d0>),
#  ('IsZombie', <ROOT.MethodProxy object at 0x7f5a30092810>),
#  ('MayNotUse', <ROOT.MethodProxy object at 0x7f5a30092850>),
#  ('Modify', <ROOT.MethodProxy object at 0x7f5a30092890>),
#  ('Notify', <ROOT.MethodProxy object at 0x7f5a300928d0>),
#  ('Obsolete', <ROOT.MethodProxy object at 0x7f5a30092910>),
#  ('Paint', <ROOT.MethodProxy object at 0x7f5a30092950>),
#  ('PaintBox', <ROOT.MethodProxy object at 0x7f5a30092990>),
#  ('PaintFrame', <ROOT.MethodProxy object at 0x7f5a300929d0>),
#  ('PaintWbox', <ROOT.MethodProxy object at 0x7f5a30092a10>),
#  ('Pop', <ROOT.MethodProxy object at 0x7f5a30092a50>),
#  ('Print', <ROOT.MethodProxy object at 0x7f5a30092a90>),
#  ('Read', <ROOT.MethodProxy object at 0x7f5a30092ad0>),
#  ('RecursiveRemove', <ROOT.MethodProxy object at 0x7f5a30092b10>),
#  ('ResetAttFill', <ROOT.MethodProxy object at 0x7f5a30092b50>),
#  ('ResetAttLine', <ROOT.MethodProxy object at 0x7f5a30092b90>),
#  ('ResetBit', <ROOT.MethodProxy object at 0x7f5a30092bd0>),
#  ('SaveAs', <ROOT.MethodProxy object at 0x7f5a30092c10>),
#  ('SaveFillAttributes', <ROOT.MethodProxy object at 0x7f5a30092c50>),
#  ('SaveLineAttributes', <ROOT.MethodProxy object at 0x7f5a30092c90>),
#  ('SavePrimitive', <ROOT.MethodProxy object at 0x7f5a30092cd0>),
#  ('SetBBoxCenter', <ROOT.MethodProxy object at 0x7f5a30092d10>),
#  ('SetBBoxCenterX', <ROOT.MethodProxy object at 0x7f5a30092d50>),
#  ('SetBBoxCenterY', <ROOT.MethodProxy object at 0x7f5a30092d90>),
#  ('SetBBoxX1', <ROOT.MethodProxy object at 0x7f5a30092dd0>),
#  ('SetBBoxX2', <ROOT.MethodProxy object at 0x7f5a30092e10>),
#  ('SetBBoxY1', <ROOT.MethodProxy object at 0x7f5a30092e50>),
#  ('SetBBoxY2', <ROOT.MethodProxy object at 0x7f5a30092e90>),
#  ('SetBit', <ROOT.MethodProxy object at 0x7f5a30092ed0>),
#  ('SetBorderMode', <ROOT.MethodProxy object at 0x7f5a30092f10>),
#  ('SetBorderSize', <ROOT.MethodProxy object at 0x7f5a30092f50>),
#  ('SetDrawOption', <ROOT.MethodProxy object at 0x7f5a30092f90>),
#  ('SetDtorOnly', <ROOT.MethodProxy object at 0x7f5a30092fd0>),
#  ('SetFillAttributes', <ROOT.MethodProxy object at 0x7f5a30093050>),
#  ('SetFillColor', <ROOT.MethodProxy object at 0x7f5a30093090>),
#  ('SetFillColorAlpha', <ROOT.MethodProxy object at 0x7f5a300930d0>),
#  ('SetFillStyle', <ROOT.MethodProxy object at 0x7f5a30093110>),
#  ('SetLineAttributes', <ROOT.MethodProxy object at 0x7f5a30093150>),
#  ('SetLineColor', <ROOT.MethodProxy object at 0x7f5a30093190>),
#  ('SetLineColorAlpha', <ROOT.MethodProxy object at 0x7f5a300931d0>),
#  ('SetLineStyle', <ROOT.MethodProxy object at 0x7f5a30093210>),
#  ('SetLineWidth', <ROOT.MethodProxy object at 0x7f5a30093250>),
#  ('SetObjectStat', <ROOT.MethodProxy object at 0x7f5a30093290>),
#  ('SetToolTipText', <ROOT.MethodProxy object at 0x7f5a300932d0>),
#  ('SetUniqueID', <ROOT.MethodProxy object at 0x7f5a30093310>),
#  ('SetX1', <ROOT.MethodProxy object at 0x7f5a30093350>),
#  ('SetX2', <ROOT.MethodProxy object at 0x7f5a30093390>),
#  ('SetY1', <ROOT.MethodProxy object at 0x7f5a300933d0>),
#  ('SetY2', <ROOT.MethodProxy object at 0x7f5a30093410>),
#  ('ShowMembers', <ROOT.MethodProxy object at 0x7f5a30093450>),
#  ('Streamer', <ROOT.MethodProxy object at 0x7f5a30093490>),
#  ('StreamerNVirtual', <ROOT.MethodProxy object at 0x7f5a300934d0>),
#  ('SysError', <ROOT.MethodProxy object at 0x7f5a30093510>),
#  ('TestBit', <ROOT.MethodProxy object at 0x7f5a30093550>),
#  ('TestBits', <ROOT.MethodProxy object at 0x7f5a30093590>),
#  ('UseCurrentStyle', <ROOT.MethodProxy object at 0x7f5a300935d0>),
#  ('Warning', <ROOT.MethodProxy object at 0x7f5a30093610>),
#  ('Write', <ROOT.MethodProxy object at 0x7f5a30093650>),
#  ('_TAttBBox2D__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a30093690>),
#  ('_TAttFill__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a300936d0>),
#  ('_TAttLine__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a30093710>),
#  ('_TBox__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a30093750>),
#  ('_TFrame__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a30093790>),
#  ('_TObject__AddToTObjectTable', <ROOT.MethodProxy object at 0x7f5a300937d0>),
#  ('_TObject__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a30093810>),
#  ('_TObject__DoError', <ROOT.MethodProxy object at 0x7f5a30093850>),
#  ('_TObject__MakeZombie', <ROOT.MethodProxy object at 0x7f5a30093890>),
#  ('_TWbox__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a300938d0>),
#  ('__assign__', <ROOT.MethodProxy object at 0x7f5a30093950>),
#  ('__cmp__',
#   <bound method TFrame.__cmp__ of <ROOT.TFrame object ("TFrame") at 0x6880400>>),
#  ('__contains__',
#   <bound method TFrame.__contains__ of <ROOT.TFrame object ("TFrame") at 0x6880400>>),
#  ('__eq__',
#   <bound method TFrame.__eq__ of <ROOT.TFrame object ("TFrame") at 0x6880400>>),
#  ('__init__', <ROOT.MethodProxy object at 0x7f5a30093910>),
#  ('__ne__',
#   <bound method TFrame.__ne__ of <ROOT.TFrame object ("TFrame") at 0x6880400>>),
#  ('ls', <ROOT.MethodProxy object at 0x7f5a300939d0>),
#  ('operator delete', <ROOT.MethodProxy object at 0x7f5a30093990>),
#  ('operator delete[]', <ROOT.MethodProxy object at 0x7f5a30093a10>),
#  ('operator new', <ROOT.MethodProxy object at 0x7f5a30093a50>),
#  ('operator new[]', <ROOT.MethodProxy object at 0x7f5a30093a90>)]
#  None
# <ROOT.TH1F object ("htemp") at 0x686ad40>[('AbstractMethod', <ROOT.MethodProxy object at 0x7f5a3009a710>),
#  ('Add', <ROOT.MethodProxy object at 0x7f5a3009a750>),
#  ('AddAt', <ROOT.MethodProxy object at 0x7f5a3009a790>),
#  ('AddBinContent', <ROOT.MethodProxy object at 0x7f5a3009a7d0>),
#  ('AddDirectory', <ROOT.MethodProxy object at 0x7f5a3009a810>),
#  ('AddDirectoryStatus', <ROOT.MethodProxy object at 0x7f5a3009a850>),
#  ('Adopt', <ROOT.MethodProxy object at 0x7f5a3009a890>),
#  ('AndersonDarlingTest', <ROOT.MethodProxy object at 0x7f5a3009a8d0>),
#  ('AppendPad', <ROOT.MethodProxy object at 0x7f5a3009a910>),
#  ('At', <ROOT.MethodProxy object at 0x7f5a3009a950>),
#  ('Browse', <ROOT.MethodProxy object at 0x7f5a3009a990>),
#  ('BufferEmpty', <ROOT.MethodProxy object at 0x7f5a3009a9d0>),
#  ('CanExtendAllAxes', <ROOT.MethodProxy object at 0x7f5a3009aa10>),
#  ('CheckedHash', <ROOT.MethodProxy object at 0x7f5a3009aa50>),
#  ('Chi2Test', <ROOT.MethodProxy object at 0x7f5a3009aa90>),
#  ('Chi2TestX', <ROOT.MethodProxy object at 0x7f5a3009aad0>),
#  ('Chisquare', <ROOT.MethodProxy object at 0x7f5a3009ab10>),
#  ('Class', <ROOT.MethodProxy object at 0x7f5a3009ab50>),
#  ('ClassName', <ROOT.MethodProxy object at 0x7f5a3009ab90>),
#  ('Class_Name', <ROOT.MethodProxy object at 0x7f5a3009abd0>),
#  ('Class_Version', <ROOT.MethodProxy object at 0x7f5a3009ac10>),
#  ('Clear', <ROOT.MethodProxy object at 0x7f5a3009ac50>),
#  ('ClearUnderflowAndOverflow', <ROOT.MethodProxy object at 0x7f5a3009ac90>),
#  ('Clone', <ROOT.MethodProxy object at 0x7f5a3009acd0>),
#  ('Compare', <ROOT.MethodProxy object at 0x7f5a3009ad10>),
#  ('ComputeIntegral', <ROOT.MethodProxy object at 0x7f5a3009ad50>),
#  ('Copy', <ROOT.MethodProxy object at 0x7f5a3009ad90>),
#  ('DeclFileLine', <ROOT.MethodProxy object at 0x7f5a3009add0>),
#  ('DeclFileName', <ROOT.MethodProxy object at 0x7f5a3009ae10>),
#  ('Delete', <ROOT.MethodProxy object at 0x7f5a3009ae90>),
#  ('Dictionary', <ROOT.MethodProxy object at 0x7f5a3009aed0>),
#  ('DirectoryAutoAdd', <ROOT.MethodProxy object at 0x7f5a3009af10>),
#  ('DistancetoLine', <ROOT.MethodProxy object at 0x7f5a3009af50>),
#  ('DistancetoPrimitive', <ROOT.MethodProxy object at 0x7f5a30093ad0>),
#  ('Divide', <ROOT.MethodProxy object at 0x7f5a3009af90>),
#  ('Draw', <ROOT.MethodProxy object at 0x7f5a3009afd0>),
#  ('DrawClass', <ROOT.MethodProxy object at 0x7f5a3009c050>),
#  ('DrawClone', <ROOT.MethodProxy object at 0x7f5a3009c090>),
#  ('DrawCopy', <ROOT.MethodProxy object at 0x7f5a3009c0d0>),
#  ('DrawNormalized', <ROOT.MethodProxy object at 0x7f5a3009c110>),
#  ('DrawPanel', <ROOT.MethodProxy object at 0x7f5a3009c150>),
#  ('Dump', <ROOT.MethodProxy object at 0x7f5a3009c190>),
#  ('Error', <ROOT.MethodProxy object at 0x7f5a3009c1d0>),
#  ('Eval', <ROOT.MethodProxy object at 0x7f5a3009c210>),
#  ('Execute', <ROOT.MethodProxy object at 0x7f5a3009c290>),
#  ('ExecuteEvent', <ROOT.MethodProxy object at 0x7f5a3009c2d0>),
#  ('ExtendAxis', <ROOT.MethodProxy object at 0x7f5a3009c310>),
#  ('FFT', <ROOT.MethodProxy object at 0x7f5a3009c350>),
#  ('Fatal', <ROOT.MethodProxy object at 0x7f5a3009c390>),
#  ('Fill', <ROOT.MethodProxy object at 0x7f5a3009c3d0>),
#  ('FillBuffer', <ROOT.MethodProxy object at 0x7f5a3009c410>),
#  ('FillN', <ROOT.MethodProxy object at 0x7f5a3009c450>),
#  ('FillRandom', <ROOT.MethodProxy object at 0x7f5a3009c490>),
#  ('FindBin', <ROOT.MethodProxy object at 0x7f5a3009c4d0>),
#  ('FindFirstBinAbove', <ROOT.MethodProxy object at 0x7f5a3009c510>),
#  ('FindFixBin', <ROOT.MethodProxy object at 0x7f5a3009c550>),
#  ('FindLastBinAbove', <ROOT.MethodProxy object at 0x7f5a3009c590>),
#  ('FindObject', <ROOT.MethodProxy object at 0x7f5a3009c5d0>),
#  ('Fit', <ROOT.MethodProxy object at 0x7f5a3009c610>),
#  ('FitOptionsMake', <ROOT.MethodProxy object at 0x7f5a3009c650>),
#  ('FitPanel', <ROOT.MethodProxy object at 0x7f5a3009c690>),
#  ('GetArray', <ROOT.MethodProxy object at 0x7f5a3009c6d0>),
#  ('GetAsymmetry', <ROOT.MethodProxy object at 0x7f5a3009c710>),
#  ('GetAt', <ROOT.MethodProxy object at 0x7f5a3009c750>),
#  ('GetAxisColor', <ROOT.MethodProxy object at 0x7f5a3009c790>),
#  ('GetBarOffset', <ROOT.MethodProxy object at 0x7f5a3009c7d0>),
#  ('GetBarWidth', <ROOT.MethodProxy object at 0x7f5a3009c810>),
#  ('GetBin', <ROOT.MethodProxy object at 0x7f5a3009c850>),
#  ('GetBinCenter', <ROOT.MethodProxy object at 0x7f5a3009c890>),
#  ('GetBinContent', <ROOT.MethodProxy object at 0x7f5a3009c8d0>),
#  ('GetBinError', <ROOT.MethodProxy object at 0x7f5a3009c910>),
#  ('GetBinErrorLow', <ROOT.MethodProxy object at 0x7f5a3009c950>),
#  ('GetBinErrorOption', <ROOT.MethodProxy object at 0x7f5a3009c990>),
#  ('GetBinErrorUp', <ROOT.MethodProxy object at 0x7f5a3009c9d0>),
#  ('GetBinLowEdge', <ROOT.MethodProxy object at 0x7f5a3009ca10>),
#  ('GetBinWidth', <ROOT.MethodProxy object at 0x7f5a3009ca50>),
#  ('GetBinWithContent', <ROOT.MethodProxy object at 0x7f5a3009ca90>),
#  ('GetBinXYZ', <ROOT.MethodProxy object at 0x7f5a3009cad0>),
#  ('GetBuffer', <ROOT.MethodProxy object at 0x7f5a3009cb10>),
#  ('GetBufferLength', <ROOT.MethodProxy object at 0x7f5a3009cb50>),
#  ('GetBufferSize', <ROOT.MethodProxy object at 0x7f5a3009cb90>),
#  ('GetCellContent', <ROOT.MethodProxy object at 0x7f5a3009cbd0>),
#  ('GetCellError', <ROOT.MethodProxy object at 0x7f5a3009cc10>),
#  ('GetCenter', <ROOT.MethodProxy object at 0x7f5a3009c250>),
#  ('GetContour', <ROOT.MethodProxy object at 0x7f5a3009cc50>),
#  ('GetContourLevel', <ROOT.MethodProxy object at 0x7f5a3009cc90>),
#  ('GetContourLevelPad', <ROOT.MethodProxy object at 0x7f5a3009ccd0>),
#  ('GetCumulative', <ROOT.MethodProxy object at 0x7f5a3009cd10>),
#  ('GetDefaultBufferSize', <ROOT.MethodProxy object at 0x7f5a3009cd50>),
#  ('GetDefaultSumw2', <ROOT.MethodProxy object at 0x7f5a3009cd90>),
#  ('GetDimension', <ROOT.MethodProxy object at 0x7f5a3009cdd0>),
#  ('GetDirectory', <ROOT.MethodProxy object at 0x7f5a3009ce10>),
#  ('GetDrawOption', <ROOT.MethodProxy object at 0x7f5a3009ce50>),
#  ('GetDtorOnly', <ROOT.MethodProxy object at 0x7f5a3009ce90>),
#  ('GetEffectiveEntries', <ROOT.MethodProxy object at 0x7f5a3009ced0>),
#  ('GetEntries', <ROOT.MethodProxy object at 0x7f5a3009cf10>),
#  ('GetFillColor', <ROOT.MethodProxy object at 0x7f5a3009cf50>),
#  ('GetFillStyle', <ROOT.MethodProxy object at 0x7f5a3009cf90>),
#  ('GetFunction', <ROOT.MethodProxy object at 0x7f5a3009cfd0>),
#  ('GetIconName', <ROOT.MethodProxy object at 0x7f5a3009d050>),
#  ('GetIntegral', <ROOT.MethodProxy object at 0x7f5a3009d090>),
#  ('GetKurtosis', <ROOT.MethodProxy object at 0x7f5a3009d0d0>),
#  ('GetLabelColor', <ROOT.MethodProxy object at 0x7f5a3009d110>),
#  ('GetLabelFont', <ROOT.MethodProxy object at 0x7f5a3009d150>),
#  ('GetLabelOffset', <ROOT.MethodProxy object at 0x7f5a3009d190>),
#  ('GetLabelSize', <ROOT.MethodProxy object at 0x7f5a3009d1d0>),
#  ('GetLineColor', <ROOT.MethodProxy object at 0x7f5a3009d210>),
#  ('GetLineStyle', <ROOT.MethodProxy object at 0x7f5a3009d250>),
#  ('GetLineWidth', <ROOT.MethodProxy object at 0x7f5a3009d290>),
#  ('GetListOfFunctions', <ROOT.MethodProxy object at 0x7f5a3009d2d0>),
#  ('GetLowEdge', <ROOT.MethodProxy object at 0x7f5a3009d310>),
#  ('GetMarkerColor', <ROOT.MethodProxy object at 0x7f5a3009d350>),
#  ('GetMarkerSize', <ROOT.MethodProxy object at 0x7f5a3009d390>),
#  ('GetMarkerStyle', <ROOT.MethodProxy object at 0x7f5a3009d3d0>),
#  ('GetMaximum', <ROOT.MethodProxy object at 0x7f5a3009d410>),
#  ('GetMaximumBin', <ROOT.MethodProxy object at 0x7f5a3009d450>),
#  ('GetMaximumStored', <ROOT.MethodProxy object at 0x7f5a3009d490>),
#  ('GetMean', <ROOT.MethodProxy object at 0x7f5a3009d4d0>),
#  ('GetMeanError', <ROOT.MethodProxy object at 0x7f5a3009d510>),
#  ('GetMinimum', <ROOT.MethodProxy object at 0x7f5a3009d550>),
#  ('GetMinimumAndMaximum', <ROOT.MethodProxy object at 0x7f5a3009d590>),
#  ('GetMinimumBin', <ROOT.MethodProxy object at 0x7f5a3009d5d0>),
#  ('GetMinimumStored', <ROOT.MethodProxy object at 0x7f5a3009d610>),
#  ('GetName', <ROOT.MethodProxy object at 0x7f5a3009d650>),
#  ('GetNbinsX', <ROOT.MethodProxy object at 0x7f5a3009d690>),
#  ('GetNbinsY', <ROOT.MethodProxy object at 0x7f5a3009d6d0>),
#  ('GetNbinsZ', <ROOT.MethodProxy object at 0x7f5a3009d710>),
#  ('GetNcells', <ROOT.MethodProxy object at 0x7f5a3009d750>),
#  ('GetNdivisions', <ROOT.MethodProxy object at 0x7f5a3009d790>),
#  ('GetNormFactor', <ROOT.MethodProxy object at 0x7f5a3009d7d0>),
#  ('GetObjectInfo', <ROOT.MethodProxy object at 0x7f5a3009d810>),
#  ('GetObjectStat', <ROOT.MethodProxy object at 0x7f5a3009d850>),
#  ('GetOption', <ROOT.MethodProxy object at 0x7f5a3009d890>),
#  ('GetPainter', <ROOT.MethodProxy object at 0x7f5a3009d8d0>),
#  ('GetQuantiles', <ROOT.MethodProxy object at 0x7f5a3009d910>),
#  ('GetRMS', <ROOT.MethodProxy object at 0x7f5a3009d950>),
#  ('GetRMSError', <ROOT.MethodProxy object at 0x7f5a3009d990>),
#  ('GetRandom', <ROOT.MethodProxy object at 0x7f5a3009d9d0>),
#  ('GetSize', <ROOT.MethodProxy object at 0x7f5a3009da10>),
#  ('GetSkewness', <ROOT.MethodProxy object at 0x7f5a3009da50>),
#  ('GetStatOverflows', <ROOT.MethodProxy object at 0x7f5a3009da90>),
#  ('GetStats', <ROOT.MethodProxy object at 0x7f5a3009dad0>),
#  ('GetStdDev', <ROOT.MethodProxy object at 0x7f5a3009db10>),
#  ('GetStdDevError', <ROOT.MethodProxy object at 0x7f5a3009db50>),
#  ('GetSum', <ROOT.MethodProxy object at 0x7f5a3009db90>),
#  ('GetSumOfWeights', <ROOT.MethodProxy object at 0x7f5a3009dbd0>),
#  ('GetSumw2', <ROOT.MethodProxy object at 0x7f5a3009dc10>),
#  ('GetSumw2N', <ROOT.MethodProxy object at 0x7f5a3009dc50>),
#  ('GetTickLength', <ROOT.MethodProxy object at 0x7f5a3009dc90>),
#  ('GetTitle', <ROOT.MethodProxy object at 0x7f5a3009dcd0>),
#  ('GetTitleFont', <ROOT.MethodProxy object at 0x7f5a3009dd10>),
#  ('GetTitleOffset', <ROOT.MethodProxy object at 0x7f5a3009dd50>),
#  ('GetTitleSize', <ROOT.MethodProxy object at 0x7f5a3009dd90>),
#  ('GetUniqueID', <ROOT.MethodProxy object at 0x7f5a3009ddd0>),
#  ('GetXaxis', <ROOT.MethodProxy object at 0x7f5a3009de10>),
#  ('GetYaxis', <ROOT.MethodProxy object at 0x7f5a3009de50>),
#  ('GetZaxis', <ROOT.MethodProxy object at 0x7f5a3009de90>),
#  ('HandleTimer', <ROOT.MethodProxy object at 0x7f5a3009ded0>),
#  ('HasInconsistentHash', <ROOT.MethodProxy object at 0x7f5a3009df10>),
#  ('Hash', <ROOT.MethodProxy object at 0x7f5a3009df50>),
#  ('ImplFileLine', <ROOT.MethodProxy object at 0x7f5a3009df90>),
#  ('ImplFileName', <ROOT.MethodProxy object at 0x7f5a3009dfd0>),
#  ('Info', <ROOT.MethodProxy object at 0x7f5a0a4bc050>),
#  ('InheritsFrom', <ROOT.MethodProxy object at 0x7f5a0a4bc090>),
#  ('Inspect', <ROOT.MethodProxy object at 0x7f5a0a4bc0d0>),
#  ('Integral', <ROOT.MethodProxy object at 0x7f5a0a4bc110>),
#  ('IntegralAndError', <ROOT.MethodProxy object at 0x7f5a0a4bc150>),
#  ('Interpolate', <ROOT.MethodProxy object at 0x7f5a0a4bc190>),
#  ('InvertBit', <ROOT.MethodProxy object at 0x7f5a0a4bc1d0>),
#  ('IsA', <ROOT.MethodProxy object at 0x7f5a0a4bc210>),
#  ('IsBinOverflow', <ROOT.MethodProxy object at 0x7f5a0a4bc250>),
#  ('IsBinUnderflow', <ROOT.MethodProxy object at 0x7f5a0a4bc290>),
#  ('IsEqual', <ROOT.MethodProxy object at 0x7f5a0a4bc2d0>),
#  ('IsFolder', <ROOT.MethodProxy object at 0x7f5a0a4bc310>),
#  ('IsOnHeap', <ROOT.MethodProxy object at 0x7f5a0a4bc350>),
#  ('IsSortable', <ROOT.MethodProxy object at 0x7f5a0a4bc390>),
#  ('IsTransparent', <ROOT.MethodProxy object at 0x7f5a0a4bc3d0>),
#  ('IsZombie', <ROOT.MethodProxy object at 0x7f5a0a4bc410>),
#  ('KolmogorovTest', <ROOT.MethodProxy object at 0x7f5a0a4bc450>),
#  ('LabelsDeflate', <ROOT.MethodProxy object at 0x7f5a0a4bc490>),
#  ('LabelsInflate', <ROOT.MethodProxy object at 0x7f5a0a4bc4d0>),
#  ('LabelsOption', <ROOT.MethodProxy object at 0x7f5a0a4bc510>),
#  ('MayNotUse', <ROOT.MethodProxy object at 0x7f5a0a4bc550>),
#  ('Merge', <ROOT.MethodProxy object at 0x7f5a0a4bc590>),
#  ('Modify', <ROOT.MethodProxy object at 0x7f5a0a4bc5d0>),
#  ('Multiply', <ROOT.MethodProxy object at 0x7f5a0a4bc610>),
#  ('Notify', <ROOT.MethodProxy object at 0x7f5a0a4bc650>),
#  ('Obsolete', <ROOT.MethodProxy object at 0x7f5a0a4bc690>),
#  ('Paint', <ROOT.MethodProxy object at 0x7f5a0a4bc6d0>),
#  ('Pop', <ROOT.MethodProxy object at 0x7f5a0a4bc710>),
#  ('Print', <ROOT.MethodProxy object at 0x7f5a0a4bc750>),
#  ('PutStats', <ROOT.MethodProxy object at 0x7f5a0a4bc790>),
#  ('Read', <ROOT.MethodProxy object at 0x7f5a0a4bc7d0>),
#  ('ReadArray', <ROOT.MethodProxy object at 0x7f5a0a4bc810>),
#  ('Rebin', <ROOT.MethodProxy object at 0x7f5a0a4bc850>),
#  ('RebinAxis', <ROOT.MethodProxy object at 0x7f5a0a4bc890>),
#  ('RebinX', <ROOT.MethodProxy object at 0x7f5a0a4bc8d0>),
#  ('Rebuild', <ROOT.MethodProxy object at 0x7f5a0a4bc910>),
#  ('RecursiveRemove', <ROOT.MethodProxy object at 0x7f5a0a4bc950>),
#  ('Reset', <ROOT.MethodProxy object at 0x7f5a0a4bc990>),
#  ('ResetAttFill', <ROOT.MethodProxy object at 0x7f5a0a4bc9d0>),
#  ('ResetAttLine', <ROOT.MethodProxy object at 0x7f5a0a4bca10>),
#  ('ResetAttMarker', <ROOT.MethodProxy object at 0x7f5a0a4bca50>),
#  ('ResetBit', <ROOT.MethodProxy object at 0x7f5a0a4bca90>),
#  ('ResetStats', <ROOT.MethodProxy object at 0x7f5a0a4bcad0>),
#  ('SaveAs', <ROOT.MethodProxy object at 0x7f5a0a4bcb10>),
#  ('SaveFillAttributes', <ROOT.MethodProxy object at 0x7f5a0a4bcb50>),
#  ('SaveLineAttributes', <ROOT.MethodProxy object at 0x7f5a0a4bcb90>),
#  ('SaveMarkerAttributes', <ROOT.MethodProxy object at 0x7f5a0a4bcbd0>),
#  ('SavePrimitive', <ROOT.MethodProxy object at 0x7f5a0a4bcc10>),
#  ('Scale', <ROOT.MethodProxy object at 0x7f5a0a4bcc50>),
#  ('Set', <ROOT.MethodProxy object at 0x7f5a0a4bcc90>),
#  ('SetAt', <ROOT.MethodProxy object at 0x7f5a0a4bccd0>),
#  ('SetAxisColor', <ROOT.MethodProxy object at 0x7f5a0a4bcd10>),
#  ('SetAxisRange', <ROOT.MethodProxy object at 0x7f5a0a4bcd50>),
#  ('SetBarOffset', <ROOT.MethodProxy object at 0x7f5a0a4bcd90>),
#  ('SetBarWidth', <ROOT.MethodProxy object at 0x7f5a0a4bcdd0>),
#  ('SetBinContent', <ROOT.MethodProxy object at 0x7f5a0a4bce10>),
#  ('SetBinError', <ROOT.MethodProxy object at 0x7f5a0a4bce50>),
#  ('SetBinErrorOption', <ROOT.MethodProxy object at 0x7f5a0a4bce90>),
#  ('SetBins', <ROOT.MethodProxy object at 0x7f5a0a4bced0>),
#  ('SetBinsLength', <ROOT.MethodProxy object at 0x7f5a0a4bcf10>),
#  ('SetBit', <ROOT.MethodProxy object at 0x7f5a0a4bcf50>),
#  ('SetBuffer', <ROOT.MethodProxy object at 0x7f5a0a4bcf90>),
#  ('SetCanExtend', <ROOT.MethodProxy object at 0x7f5a0a4bcfd0>),
#  ('SetCellContent', <ROOT.MethodProxy object at 0x7f5a0a4be050>),
#  ('SetCellError', <ROOT.MethodProxy object at 0x7f5a0a4be090>),
#  ('SetContent', <ROOT.MethodProxy object at 0x7f5a0a4be0d0>),
#  ('SetContour', <ROOT.MethodProxy object at 0x7f5a0a4be110>),
#  ('SetContourLevel', <ROOT.MethodProxy object at 0x7f5a0a4be150>),
#  ('SetDefaultBufferSize', <ROOT.MethodProxy object at 0x7f5a0a4be190>),
#  ('SetDefaultSumw2', <ROOT.MethodProxy object at 0x7f5a0a4be1d0>),
#  ('SetDirectory', <ROOT.MethodProxy object at 0x7f5a0a4be210>),
#  ('SetDrawOption', <ROOT.MethodProxy object at 0x7f5a0a4be250>),
#  ('SetDtorOnly', <ROOT.MethodProxy object at 0x7f5a0a4be2d0>),
#  ('SetEntries', <ROOT.MethodProxy object at 0x7f5a0a4be310>),
#  ('SetError', <ROOT.MethodProxy object at 0x7f5a0a4be350>),
#  ('SetFillAttributes', <ROOT.MethodProxy object at 0x7f5a0a4be390>),
#  ('SetFillColor', <ROOT.MethodProxy object at 0x7f5a0a4be3d0>),
#  ('SetFillColorAlpha', <ROOT.MethodProxy object at 0x7f5a0a4be410>),
#  ('SetFillStyle', <ROOT.MethodProxy object at 0x7f5a0a4be450>),
#  ('SetLabelColor', <ROOT.MethodProxy object at 0x7f5a0a4be490>),
#  ('SetLabelFont', <ROOT.MethodProxy object at 0x7f5a0a4be4d0>),
#  ('SetLabelOffset', <ROOT.MethodProxy object at 0x7f5a0a4be510>),
#  ('SetLabelSize', <ROOT.MethodProxy object at 0x7f5a0a4be550>),
#  ('SetLineAttributes', <ROOT.MethodProxy object at 0x7f5a0a4be590>),
#  ('SetLineColor', <ROOT.MethodProxy object at 0x7f5a0a4be5d0>),
#  ('SetLineColorAlpha', <ROOT.MethodProxy object at 0x7f5a0a4be610>),
#  ('SetLineStyle', <ROOT.MethodProxy object at 0x7f5a0a4be650>),
#  ('SetLineWidth', <ROOT.MethodProxy object at 0x7f5a0a4be690>),
#  ('SetMarkerAttributes', <ROOT.MethodProxy object at 0x7f5a0a4be6d0>),
#  ('SetMarkerColor', <ROOT.MethodProxy object at 0x7f5a0a4be710>),
#  ('SetMarkerColorAlpha', <ROOT.MethodProxy object at 0x7f5a0a4be750>),
#  ('SetMarkerSize', <ROOT.MethodProxy object at 0x7f5a0a4be790>),
#  ('SetMarkerStyle', <ROOT.MethodProxy object at 0x7f5a0a4be7d0>),
#  ('SetMaximum', <ROOT.MethodProxy object at 0x7f5a0a4be810>),
#  ('SetMinimum', <ROOT.MethodProxy object at 0x7f5a0a4be850>),
#  ('SetName', <ROOT.MethodProxy object at 0x7f5a0a4be890>),
#  ('SetNameTitle', <ROOT.MethodProxy object at 0x7f5a0a4be8d0>),
#  ('SetNdivisions', <ROOT.MethodProxy object at 0x7f5a0a4be910>),
#  ('SetNormFactor', <ROOT.MethodProxy object at 0x7f5a0a4be950>),
#  ('SetObjectStat', <ROOT.MethodProxy object at 0x7f5a0a4be990>),
#  ('SetOption', <ROOT.MethodProxy object at 0x7f5a0a4be9d0>),
#  ('SetStatOverflows', <ROOT.MethodProxy object at 0x7f5a0a4bea10>),
#  ('SetStats', <ROOT.MethodProxy object at 0x7f5a0a4bea50>),
#  ('SetTickLength', <ROOT.MethodProxy object at 0x7f5a0a4bea90>),
#  ('SetTitle', <ROOT.MethodProxy object at 0x7f5a0a4bead0>),
#  ('SetTitleFont', <ROOT.MethodProxy object at 0x7f5a0a4beb10>),
#  ('SetTitleOffset', <ROOT.MethodProxy object at 0x7f5a0a4beb50>),
#  ('SetTitleSize', <ROOT.MethodProxy object at 0x7f5a0a4beb90>),
#  ('SetUniqueID', <ROOT.MethodProxy object at 0x7f5a0a4bebd0>),
#  ('SetXTitle', <ROOT.MethodProxy object at 0x7f5a0a4bec10>),
#  ('SetYTitle', <ROOT.MethodProxy object at 0x7f5a0a4bec50>),
#  ('SetZTitle', <ROOT.MethodProxy object at 0x7f5a0a4bec90>),
#  ('ShowBackground', <ROOT.MethodProxy object at 0x7f5a0a4becd0>),
#  ('ShowMembers', <ROOT.MethodProxy object at 0x7f5a0a4bed10>),
#  ('ShowPeaks', <ROOT.MethodProxy object at 0x7f5a0a4bed50>),
#  ('Sizeof', <ROOT.MethodProxy object at 0x7f5a0a4bed90>),
#  ('Smooth', <ROOT.MethodProxy object at 0x7f5a0a4bedd0>),
#  ('SmoothArray', <ROOT.MethodProxy object at 0x7f5a0a4bee10>),
#  ('StatOverflows', <ROOT.MethodProxy object at 0x7f5a0a4bee50>),
#  ('Streamer', <ROOT.MethodProxy object at 0x7f5a0a4bee90>),
#  ('StreamerNVirtual', <ROOT.MethodProxy object at 0x7f5a0a4beed0>),
#  ('Sumw2', <ROOT.MethodProxy object at 0x7f5a0a4bef10>),
#  ('SysError', <ROOT.MethodProxy object at 0x7f5a0a4bef50>),
#  ('TestBit', <ROOT.MethodProxy object at 0x7f5a0a4bef90>),
#  ('TestBits', <ROOT.MethodProxy object at 0x7f5a0a4befd0>),
#  ('TransformHisto', <ROOT.MethodProxy object at 0x7f5a0a4c0050>),
#  ('UseCurrentStyle', <ROOT.MethodProxy object at 0x7f5a0a4c0090>),
#  ('Warning', <ROOT.MethodProxy object at 0x7f5a0a4c00d0>),
#  ('Write', <ROOT.MethodProxy object at 0x7f5a0a4c0110>),
#  ('WriteArray', <ROOT.MethodProxy object at 0x7f5a0a4c0150>),
#  ('_TArrayF__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4c0190>),
#  ('_TArray__BoundsOk', <ROOT.MethodProxy object at 0x7f5a0a4c01d0>),
#  ('_TArray__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4c0210>),
#  ('_TArray__OutOfBoundsError', <ROOT.MethodProxy object at 0x7f5a0a4c0250>),
#  ('_TAttFill__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4c0290>),
#  ('_TAttLine__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4c02d0>),
#  ('_TAttMarker__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4c0310>),
#  ('_TH1F__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4c0350>),
#  ('_TH1F__RetrieveBinContent', <ROOT.MethodProxy object at 0x7f5a0a4c0390>),
#  ('_TH1F__UpdateBinContent', <ROOT.MethodProxy object at 0x7f5a0a4c03d0>),
#  ('_TH1__AutoP2FindLimits', <ROOT.MethodProxy object at 0x7f5a0a4c0410>),
#  ('_TH1__AutoP2GetBins', <ROOT.MethodProxy object at 0x7f5a0a4c0450>),
#  ('_TH1__AutoP2GetPower2', <ROOT.MethodProxy object at 0x7f5a0a4c0490>),
#  ('_TH1__AxisChoice', <ROOT.MethodProxy object at 0x7f5a0a4c04d0>),
#  ('_TH1__BufferFill', <ROOT.MethodProxy object at 0x7f5a0a4c0510>),
#  ('_TH1__Build', <ROOT.MethodProxy object at 0x7f5a0a4c0550>),
#  ('_TH1__CheckAxisLimits', <ROOT.MethodProxy object at 0x7f5a0a4c0590>),
#  ('_TH1__CheckBinLabels', <ROOT.MethodProxy object at 0x7f5a0a4c05d0>),
#  ('_TH1__CheckBinLimits', <ROOT.MethodProxy object at 0x7f5a0a4c0610>),
#  ('_TH1__CheckConsistency', <ROOT.MethodProxy object at 0x7f5a0a4c0650>),
#  ('_TH1__CheckConsistentSubAxes', <ROOT.MethodProxy object at 0x7f5a0a4c0690>),
#  ('_TH1__CheckEqualAxes', <ROOT.MethodProxy object at 0x7f5a0a4c06d0>),
#  ('_TH1__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4c0710>),
#  ('_TH1__DoFillN', <ROOT.MethodProxy object at 0x7f5a0a4c0750>),
#  ('_TH1__DoIntegral', <ROOT.MethodProxy object at 0x7f5a0a4c0790>),
#  ('_TH1__FindNewAxisLimits', <ROOT.MethodProxy object at 0x7f5a0a4c07d0>),
#  ('_TH1__GetBinErrorSqUnchecked', <ROOT.MethodProxy object at 0x7f5a0a4c0810>),
#  ('_TH1__GetStatOverflowsBehaviour',
#   <ROOT.MethodProxy object at 0x7f5a0a4c0850>),
#  ('_TH1__IsEmpty', <ROOT.MethodProxy object at 0x7f5a0a4c0890>),
#  ('_TH1__RecomputeAxisLimits', <ROOT.MethodProxy object at 0x7f5a0a4c08d0>),
#  ('_TH1__RetrieveBinContent', <ROOT.MethodProxy object at 0x7f5a0a4c0910>),
#  ('_TH1__SameLimitsAndNBins', <ROOT.MethodProxy object at 0x7f5a0a4c0950>),
#  ('_TH1__SavePrimitiveHelp', <ROOT.MethodProxy object at 0x7f5a0a4c0990>),
#  ('_TH1__UpdateBinContent', <ROOT.MethodProxy object at 0x7f5a0a4c09d0>),
#  ('_TH1____assign__', <ROOT.MethodProxy object at 0x7f5a0a4c0a10>),
#  ('_TNamed__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4c0a50>),
#  ('_TObject__AddToTObjectTable', <ROOT.MethodProxy object at 0x7f5a0a4c0a90>),
#  ('_TObject__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4c0ad0>),
#  ('_TObject__DoError', <ROOT.MethodProxy object at 0x7f5a0a4c0b10>),
#  ('_TObject__MakeZombie', <ROOT.MethodProxy object at 0x7f5a0a4c0b50>),
#  ('__assign__', <ROOT.MethodProxy object at 0x7f5a0a4c0bd0>),
#  ('__cmp__',
#   <bound method TH1F.__cmp__ of <ROOT.TH1F object ("htemp") at 0x686ad40>>),
#  ('__contains__',
#   <bound method TH1F.__contains__ of <ROOT.TH1F object ("htemp") at 0x686ad40>>),
#  ('__eq__',
#   <bound method TH1F.__eq__ of <ROOT.TH1F object ("htemp") at 0x686ad40>>),
#  ('__getitem__',
#   <bound method TH1F.__getitem__ of <ROOT.TH1F object ("htemp") at 0x686ad40>>),
#  ('__imul__',
#   <bound method TH1F.__imul__ of <ROOT.TH1F object ("htemp") at 0x686ad40>>),
#  ('__init__', <ROOT.MethodProxy object at 0x7f5a0a4c0b90>),
#  ('__len__', <ROOT.MethodProxy object at 0x7f5a0a4c0c50>),
#  ('__ne__',
#   <bound method TH1F.__ne__ of <ROOT.TH1F object ("htemp") at 0x686ad40>>),
#  ('__setitem__', <ROOT.MethodProxy object at 0x7f5a0a4c0c10>),
#  ('_getitem__unchecked', <ROOT.MethodProxy object at 0x7f5a0a4c0cd0>),
#  ('ls', <ROOT.MethodProxy object at 0x7f5a0a4c0ed0>),
#  ('operator delete', <ROOT.MethodProxy object at 0x7f5a0a4c0f50>),
#  ('operator delete[]', <ROOT.MethodProxy object at 0x7f5a0a4c0f90>),
#  ('operator new', <ROOT.MethodProxy object at 0x7f5a0a4c0fd0>),
#  ('operator new[]', <ROOT.MethodProxy object at 0x7f5a0a4c6050>)]
#  None
# <ROOT.TPaveText object ("title") at 0x69568b0>[('AbstractMethod', <ROOT.MethodProxy object at 0x7f5a0a4c6350>),
#  ('AddBox', <ROOT.MethodProxy object at 0x7f5a0a4c6390>),
#  ('AddLine', <ROOT.MethodProxy object at 0x7f5a0a4c63d0>),
#  ('AddText', <ROOT.MethodProxy object at 0x7f5a0a4c6410>),
#  ('AppendPad', <ROOT.MethodProxy object at 0x7f5a0a4c6450>),
#  ('Browse', <ROOT.MethodProxy object at 0x7f5a0a4c6490>),
#  ('CheckedHash', <ROOT.MethodProxy object at 0x7f5a0a4c64d0>),
#  ('Class', <ROOT.MethodProxy object at 0x7f5a0a4c6510>),
#  ('ClassName', <ROOT.MethodProxy object at 0x7f5a0a4c6550>),
#  ('Class_Name', <ROOT.MethodProxy object at 0x7f5a0a4c6590>),
#  ('Class_Version', <ROOT.MethodProxy object at 0x7f5a0a4c65d0>),
#  ('Clear', <ROOT.MethodProxy object at 0x7f5a0a4c6610>),
#  ('Clone', <ROOT.MethodProxy object at 0x7f5a0a4c6650>),
#  ('Compare', <ROOT.MethodProxy object at 0x7f5a0a4c6690>),
#  ('ConvertNDCtoPad', <ROOT.MethodProxy object at 0x7f5a0a4c66d0>),
#  ('Copy', <ROOT.MethodProxy object at 0x7f5a0a4c6710>),
#  ('DeclFileLine', <ROOT.MethodProxy object at 0x7f5a0a4c6750>),
#  ('DeclFileName', <ROOT.MethodProxy object at 0x7f5a0a4c6790>),
#  ('Delete', <ROOT.MethodProxy object at 0x7f5a0a4c67d0>),
#  ('DeleteText', <ROOT.MethodProxy object at 0x7f5a0a4c6810>),
#  ('Dictionary', <ROOT.MethodProxy object at 0x7f5a0a4c6850>),
#  ('DistancetoLine', <ROOT.MethodProxy object at 0x7f5a0a4c6890>),
#  ('DistancetoPrimitive', <ROOT.MethodProxy object at 0x7f5a0a4c68d0>),
#  ('Draw', <ROOT.MethodProxy object at 0x7f5a0a4c6910>),
#  ('DrawBox', <ROOT.MethodProxy object at 0x7f5a0a4c6950>),
#  ('DrawClass', <ROOT.MethodProxy object at 0x7f5a0a4c6990>),
#  ('DrawClone', <ROOT.MethodProxy object at 0x7f5a0a4c69d0>),
#  ('DrawFile', <ROOT.MethodProxy object at 0x7f5a0a4c6a10>),
#  ('DrawPave', <ROOT.MethodProxy object at 0x7f5a0a4c6a50>),
#  ('Dump', <ROOT.MethodProxy object at 0x7f5a0a4c6a90>),
#  ('EditText', <ROOT.MethodProxy object at 0x7f5a0a4c6ad0>),
#  ('Error', <ROOT.MethodProxy object at 0x7f5a0a4c6b10>),
#  ('Execute', <ROOT.MethodProxy object at 0x7f5a0a4c6b50>),
#  ('ExecuteEvent', <ROOT.MethodProxy object at 0x7f5a0a4c6b90>),
#  ('Fatal', <ROOT.MethodProxy object at 0x7f5a0a4c6bd0>),
#  ('FindObject', <ROOT.MethodProxy object at 0x7f5a0a4c6c10>),
#  ('GetBBox', <ROOT.MethodProxy object at 0x7f5a0a4c6c50>),
#  ('GetBBoxCenter', <ROOT.MethodProxy object at 0x7f5a0a4c6c90>),
#  ('GetBorderSize', <ROOT.MethodProxy object at 0x7f5a0a4c6cd0>),
#  ('GetCornerRadius', <ROOT.MethodProxy object at 0x7f5a0a4c6d10>),
#  ('GetDrawOption', <ROOT.MethodProxy object at 0x7f5a0a4c6d50>),
#  ('GetDtorOnly', <ROOT.MethodProxy object at 0x7f5a0a4c6d90>),
#  ('GetFillColor', <ROOT.MethodProxy object at 0x7f5a0a4c6dd0>),
#  ('GetFillStyle', <ROOT.MethodProxy object at 0x7f5a0a4c6e10>),
#  ('GetIconName', <ROOT.MethodProxy object at 0x7f5a0a4c6e50>),
#  ('GetLabel', <ROOT.MethodProxy object at 0x7f5a0a4c6e90>),
#  ('GetLine', <ROOT.MethodProxy object at 0x7f5a0a4c6ed0>),
#  ('GetLineColor', <ROOT.MethodProxy object at 0x7f5a0a4c6f10>),
#  ('GetLineStyle', <ROOT.MethodProxy object at 0x7f5a0a4c6f50>),
#  ('GetLineWidth', <ROOT.MethodProxy object at 0x7f5a0a4c6f90>),
#  ('GetLineWith', <ROOT.MethodProxy object at 0x7f5a0a4c6fd0>),
#  ('GetListOfLines', <ROOT.MethodProxy object at 0x7f5a3009c050>),
#  ('GetMargin', <ROOT.MethodProxy object at 0x7f5a3009c090>),
#  ('GetName', <ROOT.MethodProxy object at 0x7f5a3009c0d0>),
#  ('GetObject', <ROOT.MethodProxy object at 0x7f5a3009c110>),
#  ('GetObjectInfo', <ROOT.MethodProxy object at 0x7f5a3009c150>),
#  ('GetObjectStat', <ROOT.MethodProxy object at 0x7f5a3009c190>),
#  ('GetOption', <ROOT.MethodProxy object at 0x7f5a3009c1d0>),
#  ('GetShadowColor', <ROOT.MethodProxy object at 0x7f5a3009c210>),
#  ('GetSize', <ROOT.MethodProxy object at 0x7f5a3009c290>),
#  ('GetTextAlign', <ROOT.MethodProxy object at 0x7f5a3009c2d0>),
#  ('GetTextAngle', <ROOT.MethodProxy object at 0x7f5a3009c310>),
#  ('GetTextColor', <ROOT.MethodProxy object at 0x7f5a3009c350>),
#  ('GetTextFont', <ROOT.MethodProxy object at 0x7f5a3009c390>),
#  ('GetTextSize', <ROOT.MethodProxy object at 0x7f5a3009c3d0>),
#  ('GetTitle', <ROOT.MethodProxy object at 0x7f5a3009c410>),
#  ('GetUniqueID', <ROOT.MethodProxy object at 0x7f5a3009c450>),
#  ('GetX1', <ROOT.MethodProxy object at 0x7f5a3009c490>),
#  ('GetX1NDC', <ROOT.MethodProxy object at 0x7f5a3009c4d0>),
#  ('GetX2', <ROOT.MethodProxy object at 0x7f5a3009c510>),
#  ('GetX2NDC', <ROOT.MethodProxy object at 0x7f5a3009c550>),
#  ('GetY1', <ROOT.MethodProxy object at 0x7f5a3009c590>),
#  ('GetY1NDC', <ROOT.MethodProxy object at 0x7f5a3009c5d0>),
#  ('GetY2', <ROOT.MethodProxy object at 0x7f5a3009c610>),
#  ('GetY2NDC', <ROOT.MethodProxy object at 0x7f5a3009c650>),
#  ('HandleTimer', <ROOT.MethodProxy object at 0x7f5a3009c690>),
#  ('HasInconsistentHash', <ROOT.MethodProxy object at 0x7f5a3009c6d0>),
#  ('Hash', <ROOT.MethodProxy object at 0x7f5a3009c710>),
#  ('HideToolTip', <ROOT.MethodProxy object at 0x7f5a3009c750>),
#  ('ImplFileLine', <ROOT.MethodProxy object at 0x7f5a3009c790>),
#  ('ImplFileName', <ROOT.MethodProxy object at 0x7f5a3009c7d0>),
#  ('Info', <ROOT.MethodProxy object at 0x7f5a3009c810>),
#  ('InheritsFrom', <ROOT.MethodProxy object at 0x7f5a3009c850>),
#  ('InsertLine', <ROOT.MethodProxy object at 0x7f5a3009c890>),
#  ('InsertText', <ROOT.MethodProxy object at 0x7f5a3009c8d0>),
#  ('Inspect', <ROOT.MethodProxy object at 0x7f5a3009c910>),
#  ('InvertBit', <ROOT.MethodProxy object at 0x7f5a3009c950>),
#  ('IsA', <ROOT.MethodProxy object at 0x7f5a3009c990>),
#  ('IsBeingResized', <ROOT.MethodProxy object at 0x7f5a3009c9d0>),
#  ('IsEqual', <ROOT.MethodProxy object at 0x7f5a3009ca10>),
#  ('IsFolder', <ROOT.MethodProxy object at 0x7f5a3009ca50>),
#  ('IsInside', <ROOT.MethodProxy object at 0x7f5a3009ca90>),
#  ('IsOnHeap', <ROOT.MethodProxy object at 0x7f5a3009cad0>),
#  ('IsSortable', <ROOT.MethodProxy object at 0x7f5a3009cb10>),
#  ('IsTransparent', <ROOT.MethodProxy object at 0x7f5a3009cb50>),
#  ('IsZombie', <ROOT.MethodProxy object at 0x7f5a3009cb90>),
#  ('MayNotUse', <ROOT.MethodProxy object at 0x7f5a3009cbd0>),
#  ('Modify', <ROOT.MethodProxy object at 0x7f5a3009cc10>),
#  ('Notify', <ROOT.MethodProxy object at 0x7f5a3009c250>),
#  ('Obsolete', <ROOT.MethodProxy object at 0x7f5a3009cc50>),
#  ('Paint', <ROOT.MethodProxy object at 0x7f5a3009cc90>),
#  ('PaintBox', <ROOT.MethodProxy object at 0x7f5a3009ccd0>),
#  ('PaintPave', <ROOT.MethodProxy object at 0x7f5a3009cd10>),
#  ('PaintPaveArc', <ROOT.MethodProxy object at 0x7f5a3009cd50>),
#  ('PaintPrimitives', <ROOT.MethodProxy object at 0x7f5a3009cd90>),
#  ('Pop', <ROOT.MethodProxy object at 0x7f5a3009cdd0>),
#  ('Print', <ROOT.MethodProxy object at 0x7f5a3009ce10>),
#  ('Read', <ROOT.MethodProxy object at 0x7f5a3009ce50>),
#  ('ReadFile', <ROOT.MethodProxy object at 0x7f5a3009ce90>),
#  ('RecursiveRemove', <ROOT.MethodProxy object at 0x7f5a3009ced0>),
#  ('ResetAttFill', <ROOT.MethodProxy object at 0x7f5a3009cf10>),
#  ('ResetAttLine', <ROOT.MethodProxy object at 0x7f5a3009cf50>),
#  ('ResetAttText', <ROOT.MethodProxy object at 0x7f5a3009cf90>),
#  ('ResetBit', <ROOT.MethodProxy object at 0x7f5a3009cfd0>),
#  ('SaveAs', <ROOT.MethodProxy object at 0x7f5a3009d050>),
#  ('SaveFillAttributes', <ROOT.MethodProxy object at 0x7f5a3009d090>),
#  ('SaveLineAttributes', <ROOT.MethodProxy object at 0x7f5a3009d0d0>),
#  ('SaveLines', <ROOT.MethodProxy object at 0x7f5a3009d110>),
#  ('SavePrimitive', <ROOT.MethodProxy object at 0x7f5a3009d150>),
#  ('SaveTextAttributes', <ROOT.MethodProxy object at 0x7f5a3009d190>),
#  ('SetAllWith', <ROOT.MethodProxy object at 0x7f5a3009d1d0>),
#  ('SetBBoxCenter', <ROOT.MethodProxy object at 0x7f5a3009d210>),
#  ('SetBBoxCenterX', <ROOT.MethodProxy object at 0x7f5a3009d250>),
#  ('SetBBoxCenterY', <ROOT.MethodProxy object at 0x7f5a3009d290>),
#  ('SetBBoxX1', <ROOT.MethodProxy object at 0x7f5a3009d2d0>),
#  ('SetBBoxX2', <ROOT.MethodProxy object at 0x7f5a3009d310>),
#  ('SetBBoxY1', <ROOT.MethodProxy object at 0x7f5a3009d350>),
#  ('SetBBoxY2', <ROOT.MethodProxy object at 0x7f5a3009d390>),
#  ('SetBit', <ROOT.MethodProxy object at 0x7f5a3009d3d0>),
#  ('SetBorderSize', <ROOT.MethodProxy object at 0x7f5a3009d410>),
#  ('SetCornerRadius', <ROOT.MethodProxy object at 0x7f5a3009d450>),
#  ('SetDrawOption', <ROOT.MethodProxy object at 0x7f5a3009d490>),
#  ('SetDtorOnly', <ROOT.MethodProxy object at 0x7f5a3009d4d0>),
#  ('SetFillAttributes', <ROOT.MethodProxy object at 0x7f5a3009d510>),
#  ('SetFillColor', <ROOT.MethodProxy object at 0x7f5a3009d550>),
#  ('SetFillColorAlpha', <ROOT.MethodProxy object at 0x7f5a3009d590>),
#  ('SetFillStyle', <ROOT.MethodProxy object at 0x7f5a3009d5d0>),
#  ('SetLabel', <ROOT.MethodProxy object at 0x7f5a3009d610>),
#  ('SetLineAttributes', <ROOT.MethodProxy object at 0x7f5a3009d650>),
#  ('SetLineColor', <ROOT.MethodProxy object at 0x7f5a3009d690>),
#  ('SetLineColorAlpha', <ROOT.MethodProxy object at 0x7f5a3009d6d0>),
#  ('SetLineStyle', <ROOT.MethodProxy object at 0x7f5a3009d710>),
#  ('SetLineWidth', <ROOT.MethodProxy object at 0x7f5a3009d750>),
#  ('SetMargin', <ROOT.MethodProxy object at 0x7f5a3009d790>),
#  ('SetName', <ROOT.MethodProxy object at 0x7f5a3009d7d0>),
#  ('SetObjectStat', <ROOT.MethodProxy object at 0x7f5a3009d810>),
#  ('SetOption', <ROOT.MethodProxy object at 0x7f5a3009d850>),
#  ('SetShadowColor', <ROOT.MethodProxy object at 0x7f5a3009d890>),
#  ('SetTextAlign', <ROOT.MethodProxy object at 0x7f5a3009d8d0>),
#  ('SetTextAngle', <ROOT.MethodProxy object at 0x7f5a3009d910>),
#  ('SetTextAttributes', <ROOT.MethodProxy object at 0x7f5a3009d950>),
#  ('SetTextColor', <ROOT.MethodProxy object at 0x7f5a3009d990>),
#  ('SetTextColorAlpha', <ROOT.MethodProxy object at 0x7f5a3009d9d0>),
#  ('SetTextFont', <ROOT.MethodProxy object at 0x7f5a3009da10>),
#  ('SetTextSize', <ROOT.MethodProxy object at 0x7f5a3009da50>),
#  ('SetTextSizePixels', <ROOT.MethodProxy object at 0x7f5a3009da90>),
#  ('SetToolTipText', <ROOT.MethodProxy object at 0x7f5a3009dad0>),
#  ('SetUniqueID', <ROOT.MethodProxy object at 0x7f5a3009db10>),
#  ('SetX1', <ROOT.MethodProxy object at 0x7f5a3009db50>),
#  ('SetX1NDC', <ROOT.MethodProxy object at 0x7f5a3009db90>),
#  ('SetX2', <ROOT.MethodProxy object at 0x7f5a3009dbd0>),
#  ('SetX2NDC', <ROOT.MethodProxy object at 0x7f5a3009dc10>),
#  ('SetY1', <ROOT.MethodProxy object at 0x7f5a3009dc50>),
#  ('SetY1NDC', <ROOT.MethodProxy object at 0x7f5a3009dc90>),
#  ('SetY2', <ROOT.MethodProxy object at 0x7f5a3009dcd0>),
#  ('SetY2NDC', <ROOT.MethodProxy object at 0x7f5a3009dd10>),
#  ('ShowMembers', <ROOT.MethodProxy object at 0x7f5a3009dd50>),
#  ('Streamer', <ROOT.MethodProxy object at 0x7f5a3009dd90>),
#  ('StreamerNVirtual', <ROOT.MethodProxy object at 0x7f5a3009ddd0>),
#  ('SysError', <ROOT.MethodProxy object at 0x7f5a3009de10>),
#  ('TestBit', <ROOT.MethodProxy object at 0x7f5a3009de50>),
#  ('TestBits', <ROOT.MethodProxy object at 0x7f5a3009de90>),
#  ('UseCurrentStyle', <ROOT.MethodProxy object at 0x7f5a3009ded0>),
#  ('Warning', <ROOT.MethodProxy object at 0x7f5a3009df10>),
#  ('Write', <ROOT.MethodProxy object at 0x7f5a3009df50>),
#  ('_TAttBBox2D__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a3009df90>),
#  ('_TAttFill__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a3009dfd0>),
#  ('_TAttLine__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4be290>),
#  ('_TAttText__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4be050>),
#  ('_TBox__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4be090>),
#  ('_TObject__AddToTObjectTable', <ROOT.MethodProxy object at 0x7f5a0a4be0d0>),
#  ('_TObject__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4be110>),
#  ('_TObject__DoError', <ROOT.MethodProxy object at 0x7f5a0a4be150>),
#  ('_TObject__MakeZombie', <ROOT.MethodProxy object at 0x7f5a0a4be190>),
#  ('_TPaveText__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4be1d0>),
#  ('_TPave__CheckTObjectHashConsistency',
#   <ROOT.MethodProxy object at 0x7f5a0a4be210>),
#  ('__assign__', <ROOT.MethodProxy object at 0x7f5a0a4be2d0>),
#  ('__cmp__',
#   <bound method TPaveText.__cmp__ of <ROOT.TPaveText object ("title") at 0x69568b0>>),
#  ('__contains__',
#   <bound method TPaveText.__contains__ of <ROOT.TPaveText object ("title") at 0x69568b0>>),
#  ('__eq__',
#   <bound method TPaveText.__eq__ of <ROOT.TPaveText object ("title") at 0x69568b0>>),
#  ('__init__', <ROOT.MethodProxy object at 0x7f5a0a4be250>),
#  ('__len__', <ROOT.MethodProxy object at 0x7f5a0a4be350>),
#  ('__ne__',
#   <bound method TPaveText.__ne__ of <ROOT.TPaveText object ("title") at 0x69568b0>>),
#  ('ls', <ROOT.MethodProxy object at 0x7f5a0a4be310>),
#  ('operator delete', <ROOT.MethodProxy object at 0x7f5a0a4be390>),
#  ('operator delete[]', <ROOT.MethodProxy object at 0x7f5a0a4be3d0>),
#  ('operator new', <ROOT.MethodProxy object at 0x7f5a0a4be410>),
#  ('operator new[]', <ROOT.MethodProxy object at 0x7f5a0a4be450>)]
#  None

# %% [markdown]
# Now that we know what's in our trees and gotten a quick look to sanity-check the data, we'll get started trying to tackle the many gigs of data that are at hand. pyROOT is not the right tool for crunching this much data, so let's move on to preparing a C++ class to do the number crunching.

# %%
firstLookTree.MakeClass("hatsTrees")
# Out:
# 0
# Info in <TTreePlayer::MakeClass>: Files: hatsTrees.h and hatsTrees.C generated from TTree: tree

# %% [markdown]
# Let's see what this made for us:

# %%
# !ls -lrth
# Out:
# total 228K
# -rw-r--r-- 1 cms.oalterka cms  863 May 29 18:10 README.md
# -rw-r--r-- 1 cms.oalterka cms  501 May 29 18:10 hatsConfig.ini
# -rw-r--r-- 1 cms.oalterka cms  60K May 29 18:10 openFirstLook.png
# -rw-r--r-- 1 cms.oalterka cms 5.8K May 29 18:10 prepareCppClass.ipynb
# drwxr-xr-x 3 cms.oalterka cms   91 May 29 18:10 sample_code
# -rw-r--r-- 1 cms.oalterka cms 7.9K May 29 19:02 backgroundHists.ipynb
# -rw-r--r-- 1 cms.oalterka cms  42K May 29 19:21 hatsTrees.h
# -rw-r--r-- 1 cms.oalterka cms 1.5K May 29 19:21 hatsTrees.C
# -rw-r--r-- 1 cms.oalterka cms  96K May 29 19:21 firstLook.ipynb

# %% [markdown]
# Our aim is to use this C++ class to do the CPU-intensive work of our analysis, but to keep it as a "plugin" inside our pyroot framework.

# %% [markdown]
# >Please move on to the notebook `prepareCppClass.ipynb`
